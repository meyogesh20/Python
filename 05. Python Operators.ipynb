# %% [markdown]
# # Python Operators
#
# ### Python divides the operators in the following groups:
#
# 1. Arithmetic operators
# 2. Assignment operators
# 3. Comparison operators
# 4. Logical operators
# 5. Identity operators
# 6. Membership operators
# 7. Bitwise operators
#
# #### 1. Arithmetic operators
# - Arithmetic operators are used with numeric values to perform common mathematical operations:
# ![image.png](attachment:67245503-7d04-432a-a7e5-6d4de73936d0.png)<br>
#
# #### 2. Assignment operators
# - Assignment operators are used to assign values to variables:
# ![image.png](attachment:b4f7b562-b9af-4980-b5eb-2d8c382d40d5.png)<br>
#
# #### 3. Comparison operators
# - Comparison operators are used to compare two values:
# ![image.png](attachment:2d8f7834-7f71-4cf6-ab41-0262069c907a.png)<br>
#
# #### 4. Logical operators
# - Logical operators are used to combine conditional statements:
# ![image.png](attachment:9f30e82e-d6f1-4583-abb8-3640cf0459e0.png)<br>
#
# #### 5. Identity operators
# - Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location:
# ![image.png](attachment:7ecd245a-ce9d-4d59-abb9-7f0b15e23781.png)<br>
#
# #### 6. Membership operators
# - Membership operators are used to test if a sequence is presented in an object:
# ![image.png](attachment:3f0c430c-d127-4c5f-8d92-649917e8b472.png)<br>
#
# #### 7. Bitwise operators
# - Bitwise operators are used to compare (binary) numbers:
# ![image.png](attachment:f4314396-6c47-4a9f-b92a-1ed04ab3516b.png)<br>

# %% [markdown]
# # Operator Precedence
# - Operator precedence describes the order in which operations are performed.
# ![image.png](attachment:bf32df2f-0652-4233-ae34-3fa72dbd6b11.png)<br>

# %% [markdown]
# ### Comparison Operator

# %% [markdown]
# Let's now work through quick examples of each of these.
#
# #### Equal

# %%
2 == 2
# Out:
# True

# %%
1 == 0
# Out:
# False

# %% [markdown]
# Note that <code>==</code> is a <em>comparison</em> operator, while <code>=</code> is an <em>assignment</em> operator.

# %% [markdown]
# #### Not Equal

# %%
2 != 1
# Out:
# True

# %%
2 != 2
# Out:
# False

# %% [markdown]
# #### Greater Than

# %%
2 > 1
# Out:
# True

# %%
2 > 4
# Out:
# False

# %% [markdown]
# #### Less Than

# %%
2 < 4
# Out:
# True

# %%
2 < 1
# Out:
# False

# %% [markdown]
# #### Greater Than or Equal to

# %%
2 >= 2
# Out:
# True

# %%
2 >= 1
# Out:
# True

# %% [markdown]
# #### Less than or Equal to

# %%
2 <= 2
# Out:
# True

# %%
2 <= 4
# Out:
# True

# %% [markdown]
# # Chained Comparison Operators
#
# An interesting feature of Python is the ability to *chain* multiple comparisons to perform a more complex test. You can use these chained comparisons as shorthand for larger Boolean Expressions.
#
# We will learn how to chain comparison operators and we will also introduce two other important statements in Python: **and** and **or**.
#
# Let's look at a few examples of using chains:

# %%
1 < 2 < 3
# Out:
# True

# %% [markdown]
# The above statement checks if 1 was less than 2 **and** if 2 was less than 3. We could have written this using an **and** statement in Python:

# %%
1<2 and 2<3
# Out:
# True

# %% [markdown]
# The above checks if 3 is larger than both of the other numbers, so you could use **and** to rewrite it as:

# %%
1<3 and 3>2
# Out:
# True

# %% [markdown]
# It's important to note that Python is checking both instances of the comparisons. We can also use **or** to write comparisons in Python. For example:

# %%
1==2 or 2<3
# Out:
# True

# %% [markdown]
# Note how it was true; this is because with the **or** operator, we only need one *or* the other to be true. Let's see one more example to drive this home:

# %%
1==1 or 100==1
# Out:
# True

# %% [markdown]
# # End of the Session
